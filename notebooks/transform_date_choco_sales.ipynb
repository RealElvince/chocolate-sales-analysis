# %%
import pandas as pd

# %%
data = pd.read_excel("../src/chocolate_sales.xlsx")

# %%
data
# Out:
#           Sales_Person    Country              Product                 Date  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  2022-04-01 00:00:00
# 1          Van Tuxwell      India        85% Dark Bars  2022-01-08 00:00:00
# 2         Gigi Bohling      India  Peanut Butter Cubes  2022-07-07 00:00:00
# 3         Jan Morforth  Australia  Peanut Butter Cubes           27/04/2022
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes           24/02/2022
# ...                ...        ...                  ...                  ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims           17/05/2024
# 3278    Jehu Rudeforth        USA           White Choc  2024-07-06 00:00:00
# 3279      Ches Bonnell     Canada  Organic Choco Syrup           26/07/2024
# 3280    Dotty Strutley      India              Eclairs           28/07/2024
# 3281  Karlen McCaffrey      India       70% Dark Bites           23/05/2024
#
#         Amount  Boxes_Shipped
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data
# Out:
#           Sales_Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco 2022-04-01   5320.00
# 1          Van Tuxwell      India        85% Dark Bars 2022-01-08   7896.00
# 2         Gigi Bohling      India  Peanut Butter Cubes 2022-07-07   4501.00
# 3         Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27  12726.00
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24  13685.00
# ...                ...        ...                  ...        ...       ...
# 3277  Karlen McCaffrey  Australia  Spicy Special Slims 2024-05-17   5303.58
# 3278    Jehu Rudeforth        USA           White Choc 2024-07-06   7339.32
# 3279      Ches Bonnell     Canada  Organic Choco Syrup 2024-07-26    616.09
# 3280    Dotty Strutley      India              Eclairs 2024-07-28   2504.62
# 3281  Karlen McCaffrey      India       70% Dark Bites 2024-05-23   5915.87
#
#       Boxes_Shipped
# 0               180
# ...

# %%
data.to_excel("../src/cholocate_sales_cleaned.xlsx",index=False)
